# %% [markdown]
# <a href="https://colab.research.google.com/github/notacodingguy/tensorflow1/blob/master/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fbprophet import Prophet

# %%
avocado_df = pd.read_csv("avocado.csv")

# %%
avocado_df.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
# 5           5  2015-11-22          1.26  ...  conventional  2015  Albany
# 6           6  2015-11-15          0.99  ...  conventional  2015  Albany
# 7           7  2015-11-08          0.98  ...  conventional  2015  Albany
# 8           8  2015-11-01          1.02  ...  conventional  2015  Albany
# 9           9  2015-10-25          1.07  ...  conventional  2015  Albany
#
# [10 rows x 14 columns]

# %%
avocado_df.tail(20)
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 18229           4  2018-02-25          1.49  ...  organic  2018              West
# 18230           5  2018-02-18          1.64  ...  organic  2018              West
# 18231           6  2018-02-11          1.47  ...  organic  2018              West
# 18232           7  2018-02-04          1.41  ...  organic  2018              West
# 18233           8  2018-01-28          1.80  ...  organic  2018              West
# 18234           9  2018-01-21          1.83  ...  organic  2018              West
# 18235          10  2018-01-14          1.82  ...  organic  2018              West
# 18236          11  2018-01-07          1.48  ...  organic  2018              West
# 18237           0  2018-03-25          1.62  ...  organic  2018  WestTexNewMexico
# 18238           1  2018-03-18          1.56  ...  organic  2018  WestTexNewMexico
# ...

# %%
avocado_df = avocado_df.sort_values("Date")

# %%
avocado_df.tail(20)
# Out:
#        Unnamed: 0        Date  ...  year               region
# 8682            0  2018-03-25  ...  2018  HartfordSpringfield
# 8610            0  2018-03-25  ...  2018        DallasFtWorth
# 17961           0  2018-03-25  ...  2018   NorthernNewEngland
# 18009           0  2018-03-25  ...  2018           Pittsburgh
# 18213           0  2018-03-25  ...  2018              TotalUS
# 9114            0  2018-03-25  ...  2018     WestTexNewMexico
# 17721           0  2018-03-25  ...  2018             Columbus
# 8934            0  2018-03-25  ...  2018      RichmondNorfolk
# 9030            0  2018-03-25  ...  2018            Southeast
# 8622            0  2018-03-25  ...  2018               Denver
# 17757           0  2018-03-25  ...  2018              Detroit
# 17781           0  2018-03-25  ...  2018           GreatLakes
# 8982            0  2018-03-25  ...  2018         SanFrancisco
# 8946            0  2018-03-25  ...  2018              Roanoke
# ...

# %%
plt.figure(figsize=(10, 10))
plt.plot(avocado_df["Date"], avocado_df["AveragePrice"])

# %%
avocado_prophet_df = avocado_df[["Date", "AveragePrice"]]

# %%
avocado_prophet_df
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 11829  2015-01-04          1.46
# 11777  2015-01-04          1.70
# 675    2015-01-04          0.99
# 1247   2015-01-04          0.92
# ...           ...           ...
# 8670   2018-03-25          1.21
# 17997  2018-03-25          1.52
# 17733  2018-03-25          1.46
# 8706   2018-03-25          1.05
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
avocado_prophet_df = avocado_prophet_df.rename(columns = {"Date":"ds", "AveragePrice":"y"})

# %%
m=Prophet()
m.fit(avocado_prophet_df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future =m.make_future_dataframe(365)
forecast = m.predict(future)

# %%
forecast
# Out:
#               ds     trend  ...  multiplicative_terms_upper      yhat
# 0     2015-01-04  1.498787  ...                         0.0  1.384431
# 1     2015-01-04  1.498787  ...                         0.0  1.384431
# 2     2015-01-04  1.498787  ...                         0.0  1.384431
# 3     2015-01-04  1.498787  ...                         0.0  1.384431
# 4     2015-01-04  1.498787  ...                         0.0  1.384431
# ...          ...       ...  ...                         ...       ...
# 18609 2019-03-21  1.174365  ...                         0.0  1.086974
# 18610 2019-03-22  1.173659  ...                         0.0  1.087979
# 18611 2019-03-23  1.172954  ...                         0.0  1.089261
# 18612 2019-03-24  1.172248  ...                         0.0  1.090799
# 18613 2019-03-25  1.171543  ...                         0.0  1.092566
#
# [18614 rows x 16 columns]

# %%
figure = m.plot(forecast, xlabel = "Year", ylabel ="Price" )

# %%
figure1 = m.plot_components(forecast)

# %%
avocado_df_sample = avocado_df[avocado_df['region']=='West']

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 2755           51  2015-01-04          0.89  ...  conventional  2015    West
# 11881          51  2015-01-04          1.40  ...       organic  2015    West
# 2754           50  2015-01-11          0.95  ...  conventional  2015    West
# 11880          50  2015-01-11          1.39  ...       organic  2015    West
# 11879          49  2015-01-18          1.33  ...       organic  2015    West
# ...           ...         ...           ...  ...           ...   ...     ...
# 9104            2  2018-03-11          1.00  ...  conventional  2018    West
# 9103            1  2018-03-18          0.99  ...  conventional  2018    West
# 18226           1  2018-03-18          1.73  ...       organic  2018    West
# 9102            0  2018-03-25          0.93  ...  conventional  2018    West
# 18225           0  2018-03-25          1.60  ...       organic  2018    West
#
# [338 rows x 14 columns]

# %%
avocado_df_sample = avocado_df.sort_values("Date")

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  ...  year               region
# 11569          51  2015-01-04  ...  2015            Southeast
# 9593           51  2015-01-04  ...  2015              Chicago
# 10009          51  2015-01-04  ...  2015   HarrisburgScranton
# 1819           51  2015-01-04  ...  2015           Pittsburgh
# 9333           51  2015-01-04  ...  2015                Boise
# ...           ...         ...  ...   ...                  ...
# 8574            0  2018-03-25  ...  2018              Chicago
# 9018            0  2018-03-25  ...  2018         SouthCentral
# 17625           0  2018-03-25  ...  2018  BaltimoreWashington
# 18033           0  2018-03-25  ...  2018             Portland
# 8814            0  2018-03-25  ...  2018              NewYork
#
# [18249 rows x 14 columns]

# %%
plt.figure(figsize=(10,10))
plt.plot(avocado_df_sample['Date'], avocado_df_sample['AveragePrice'])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
avocado_df_sample = avocado_df_sample.rename(columns={'Date':'ds', 'AveragePrice':'y'})

# %%
m = Prophet()
m.fit(avocado_df_sample)
# Forcasting into the future
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
figure = m.plot(forecast, xlabel='Date', ylabel='Price')

# %%
figure3 = m.plot_components(forecast)
